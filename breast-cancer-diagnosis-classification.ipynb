# %% [markdown]
# # Import Libraries & Load Data

# %%
import json
import math
import os
import cv2
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras import layers
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.applications.densenet import DenseNet201
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score, confusion_matrix
import scipy
from tqdm import tqdm
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
import warnings
warnings.simplefilter("ignore")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
            img = cv2.resize(img, (RESIZE,RESIZE))          
            IMG.append(np.array(img))
            
    return IMG

benign_train = np.array(Dataset_loader('/kaggle/input/breast-cancer-diagnosis/breast-cancer-dataset/Train/Benign',224))
malign_train = np.array(Dataset_loader('/kaggle/input/breast-cancer-diagnosis/breast-cancer-dataset/Train/Malignant',224))
benign_test = np.array(Dataset_loader('/kaggle/input/breast-cancer-diagnosis/breast-cancer-dataset/Test/Benign',224))
malign_test = np.array(Dataset_loader('/kaggle/input/breast-cancer-diagnosis/breast-cancer-dataset/Test/Malignant',224))
# Out:
# 100%|██████████| 640/640 [00:06<00:00, 97.35it/s]
# 100%|██████████| 640/640 [00:05<00:00, 124.12it/s]
# 100%|██████████| 120/120 [00:01<00:00, 110.07it/s]
# 100%|██████████| 120/120 [00:01<00:00, 89.53it/s]

# %% [markdown]
# # Data Preprocessing

# %%
# Create labels
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# %%
# Merge data 
x_train = np.concatenate((benign_train, malign_train), axis = 0)
y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
x_test = np.concatenate((benign_test, malign_test), axis = 0)
y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# %%
# Shuffle train data
s = np.arange(x_train.shape[0])
np.random.shuffle(s)
x_train = x_train[s]
y_train = y_train[s]

# %%
# Shuffle test data
s = np.arange(x_test.shape[0])
np.random.shuffle(s)
x_test = x_test[s]
y_test = y_test[s]

# %%
# To categorical
y_train = to_categorical(y_train, num_classes= 2)
y_test = to_categorical(y_test, num_classes= 2)

# %%
# split dataset into train and validation
x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, 
    test_size=0.2, 
    random_state=11
)

# %%
# visualization image
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(x_train[i], interpolation='nearest')
plt.show()

# %%
BATCH_SIZE = 16

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True,  # randomly flip images
    )

# %% [markdown]
# # Define Model

# %%
def build_model(backbone, lr=1e-4):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(2, activation='softmax'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=lr),
        metrics=['accuracy']
    )
    
    return model

resnet = DenseNet201(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

model = build_model(resnet ,lr = 1e-4)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d (G  (None, 1920)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1920)              0
#
#  batch_normalization (BatchN  (None, 1920)             7680
#  ormalization)
#
#  dense (Dense)               (None, 2)                 3842
#
# =================================================================
# Total params: 18,333,506
# Trainable params: 18,100,610
# Non-trainable params: 232,896
# _________________________________________________________________

# %% [markdown]
# # Training & Evaluation

# %%
learn_control = ReduceLROnPlateau(monitor='val_acc', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)


history = model.fit_generator(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=100,
    validation_data=(x_val, y_val),
)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 153s 340ms/step - loss: 0.6806 - accuracy: 0.6426 - val_loss: 2044.1973 - val_accuracy: 0.4688
# Epoch 2/100
# 64/64 [==============================] - 16s 253ms/step - loss: 0.5129 - accuracy: 0.7764 - val_loss: 63.4372 - val_accuracy: 0.4688
# Epoch 3/100
# 64/64 [==============================] - 18s 275ms/step - loss: 0.5180 - accuracy: 0.7744 - val_loss: 41.9739 - val_accuracy: 0.4688
# Epoch 4/100
# 64/64 [==============================] - 16s 252ms/step - loss: 0.5050 - accuracy: 0.7666 - val_loss: 6.6281 - val_accuracy: 0.5391
# Epoch 5/100
# 64/64 [==============================] - 17s 266ms/step - loss: 0.4580 - accuracy: 0.8018 - val_loss: 1.2427 - val_accuracy: 0.6328
# Epoch 6/100
# 64/64 [==============================] - 16s 253ms/step - loss: 0.4602 - accuracy: 0.7803 - val_loss: 19.3345 - val_accuracy: 0.4961
# Epoch 7/100
# 64/64 [==============================] - 16s 253ms/step - loss: 0.4617 - accuracy: 0.7939 - val_loss: 3.4878 - val_accuracy: 0.5703
# Epoch 8/100
# 64/64 [==============================] - 17s 265ms/step - loss: 0.4569 - accuracy: 0.7773 - val_loss: 0.4097 - val_accuracy: 0.8672
# Epoch 9/100
# 64/64 [==============================] - 16s 254ms/step - loss: 0.4695 - accuracy: 0.7861 - val_loss: 0.6824 - val_accuracy: 0.7812
# Epoch 10/100
# 64/64 [==============================] - 17s 270ms/step - loss: 0.4726 - accuracy: 0.7832 - val_loss: 16.3611 - val_accuracy: 0.4688
# Epoch 11/100
# 64/64 [==============================] - 16s 249ms/step - loss: 0.4282 - accuracy: 0.8125 - val_loss: 0.2920 - val_accuracy: 0.8828
# Epoch 12/100
# 64/64 [==============================] - 17s 263ms/step - loss: 0.4275 - accuracy: 0.8154 - val_loss: 0.6629 - val_accuracy: 0.6523
# Epoch 13/100
# 64/64 [==============================] - 16s 252ms/step - loss: 0.4507 - accuracy: 0.7959 - val_loss: 1.7193 - val_accuracy: 0.5391
# Epoch 14/100
# 64/64 [==============================] - 17s 264ms/step - loss: 0.4497 - accuracy: 0.8096 - val_loss: 11.7142 - val_accuracy: 0.5469
# Epoch 15/100
# 64/64 [==============================] - 16s 251ms/step - loss: 0.4456 - accuracy: 0.8115 - val_loss: 1.5031 - val_accuracy: 0.6445
# Epoch 16/100
# 64/64 [==============================] - 17s 264ms/step - loss: 0.4554 - accuracy: 0.7939 - val_loss: 1.1402 - val_accuracy: 0.5781
# Epoch 17/100
# 64/64 [==============================] - 16s 255ms/step - loss: 0.4657 - accuracy: 0.7998 - val_loss: 1.1929 - val_accuracy: 0.5312
# Epoch 18/100
# 64/64 [==============================] - 16s 252ms/step - loss: 0.4302 - accuracy: 0.8018 - val_loss: 0.3057 - val_accuracy: 0.8984
# Epoch 19/100
# 64/64 [==============================] - 18s 275ms/step - loss: 0.4572 - accuracy: 0.7861 - val_loss: 0.3547 - val_accuracy: 0.8711
# Epoch 20/100
# 64/64 [==============================] - 16s 252ms/step - loss: 0.4572 - accuracy: 0.7920 - val_loss: 0.4208 - val_accuracy: 0.8906
# Epoch 21/100
# 64/64 [==============================] - 17s 262ms/step - loss: 0.4176 - accuracy: 0.8105 - val_loss: 0.3394 - val_accuracy: 0.8945
# Epoch 22/100
# 64/64 [==============================] - 18s 277ms/step - loss: 0.4283 - accuracy: 0.7939 - val_loss: 0.3904 - val_accuracy: 0.8086
# Epoch 23/100
# 64/64 [==============================] - 16s 253ms/step - loss: 0.3969 - accuracy: 0.8232 - val_loss: 1.3283 - val_accuracy: 0.5312
# Epoch 24/100
# 64/64 [==============================] - 17s 265ms/step - loss: 0.4041 - accuracy: 0.8281 - val_loss: 1.0314 - val_accuracy: 0.6953
# Epoch 25/100
# 64/64 [==============================] - 16s 255ms/step - loss: 0.4382 - accuracy: 0.8086 - val_loss: 1.4950 - val_accuracy: 0.6016
# Epoch 26/100
# 64/64 [==============================] - 17s 268ms/step - loss: 0.3841 - accuracy: 0.8271 - val_loss: 9.0449 - val_accuracy: 0.5234
# Epoch 27/100
# 64/64 [==============================] - 16s 254ms/step - loss: 0.4301 - accuracy: 0.8066 - val_loss: 0.4155 - val_accuracy: 0.8477
# Epoch 28/100
# 64/64 [==============================] - 17s 266ms/step - loss: 0.4050 - accuracy: 0.8232 - val_loss: 1.5991 - val_accuracy: 0.6328
# Epoch 29/100
# 64/64 [==============================] - 16s 254ms/step - loss: 0.4294 - accuracy: 0.8066 - val_loss: 0.7214 - val_accuracy: 0.6719
# Epoch 30/100
# 64/64 [==============================] - 16s 254ms/step - loss: 0.4252 - accuracy: 0.8086 - val_loss: 0.6270 - val_accuracy: 0.8242
# Epoch 31/100
# 64/64 [==============================] - 17s 267ms/step - loss: 0.4106 - accuracy: 0.8135 - val_loss: 0.5206 - val_accuracy: 0.7266
# Epoch 32/100
# 64/64 [==============================] - 16s 255ms/step - loss: 0.4120 - accuracy: 0.8145 - val_loss: 0.4408 - val_accuracy: 0.8164
# Epoch 33/100
# 64/64 [==============================] - 17s 268ms/step - loss: 0.3997 - accuracy: 0.8203 - val_loss: 0.3526 - val_accuracy: 0.8633
# Epoch 34/100
# 64/64 [==============================] - 16s 251ms/step - loss: 0.4083 - accuracy: 0.8203 - val_loss: 0.8555 - val_accuracy: 0.5508
# Epoch 35/100
# 64/64 [==============================] - 16s 252ms/step - loss: 0.4089 - accuracy: 0.8223 - val_loss: 0.6277 - val_accuracy: 0.6836
# Epoch 36/100
# 64/64 [==============================] - 17s 263ms/step - loss: 0.4136 - accuracy: 0.8154 - val_loss: 0.3948 - val_accuracy: 0.7773
# Epoch 37/100
# 64/64 [==============================] - 16s 253ms/step - loss: 0.4207 - accuracy: 0.8164 - val_loss: 0.6649 - val_accuracy: 0.7148
# Epoch 38/100
# 64/64 [==============================] - 17s 265ms/step - loss: 0.4158 - accuracy: 0.8154 - val_loss: 0.7969 - val_accuracy: 0.5664
# Epoch 39/100
# 64/64 [==============================] - 16s 253ms/step - loss: 0.4352 - accuracy: 0.8135 - val_loss: 1.2887 - val_accuracy: 0.7461
# Epoch 40/100
# 64/64 [==============================] - 17s 266ms/step - loss: 0.4057 - accuracy: 0.8213 - val_loss: 0.9811 - val_accuracy: 0.7344
# Epoch 41/100
# 64/64 [==============================] - 16s 250ms/step - loss: 0.3938 - accuracy: 0.8232 - val_loss: 0.4196 - val_accuracy: 0.7930
# Epoch 42/100
# 64/64 [==============================] - 17s 264ms/step - loss: 0.4165 - accuracy: 0.8135 - val_loss: 7.0389 - val_accuracy: 0.4961
# Epoch 43/100
# 64/64 [==============================] - 16s 251ms/step - loss: 0.4148 - accuracy: 0.8135 - val_loss: 0.7218 - val_accuracy: 0.7812
# Epoch 44/100
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3683 - accuracy: 0.8340 - val_loss: 0.2429 - val_accuracy: 0.8906
# Epoch 45/100
# 64/64 [==============================] - 17s 262ms/step - loss: 0.4437 - accuracy: 0.8086 - val_loss: 0.6803 - val_accuracy: 0.7617
# Epoch 46/100
# 64/64 [==============================] - 16s 253ms/step - loss: 0.3952 - accuracy: 0.8193 - val_loss: 0.8853 - val_accuracy: 0.6133
# Epoch 47/100
# 64/64 [==============================] - 17s 263ms/step - loss: 0.4078 - accuracy: 0.8057 - val_loss: 0.3128 - val_accuracy: 0.8438
# Epoch 48/100
# 64/64 [==============================] - 16s 252ms/step - loss: 0.3996 - accuracy: 0.8369 - val_loss: 0.3489 - val_accuracy: 0.8359
# Epoch 49/100
# 64/64 [==============================] - 17s 265ms/step - loss: 0.4116 - accuracy: 0.8213 - val_loss: 0.5119 - val_accuracy: 0.7812
# Epoch 50/100
# 64/64 [==============================] - 16s 249ms/step - loss: 0.4241 - accuracy: 0.8174 - val_loss: 0.3810 - val_accuracy: 0.8203
# Epoch 51/100
# 64/64 [==============================] - 17s 265ms/step - loss: 0.3822 - accuracy: 0.8486 - val_loss: 4.5557 - val_accuracy: 0.5352
# Epoch 52/100
# 64/64 [==============================] - 16s 248ms/step - loss: 0.4227 - accuracy: 0.8203 - val_loss: 0.2575 - val_accuracy: 0.8945
# Epoch 53/100
# 64/64 [==============================] - 17s 266ms/step - loss: 0.3965 - accuracy: 0.8223 - val_loss: 0.3358 - val_accuracy: 0.8398
# Epoch 54/100
# 64/64 [==============================] - 17s 258ms/step - loss: 0.4169 - accuracy: 0.8145 - val_loss: 0.4822 - val_accuracy: 0.7344
# Epoch 55/100
# 64/64 [==============================] - 16s 252ms/step - loss: 0.4028 - accuracy: 0.8213 - val_loss: 0.2351 - val_accuracy: 0.9102
# Epoch 56/100
# 64/64 [==============================] - 17s 264ms/step - loss: 0.3886 - accuracy: 0.8262 - val_loss: 2.7267 - val_accuracy: 0.5312
# Epoch 57/100
# 64/64 [==============================] - 16s 252ms/step - loss: 0.3818 - accuracy: 0.8301 - val_loss: 0.9137 - val_accuracy: 0.5820
# Epoch 58/100
# 64/64 [==============================] - 17s 267ms/step - loss: 0.3796 - accuracy: 0.8291 - val_loss: 0.4656 - val_accuracy: 0.8125
# Epoch 59/100
# 64/64 [==============================] - 16s 250ms/step - loss: 0.3976 - accuracy: 0.8271 - val_loss: 0.3582 - val_accuracy: 0.8281
# Epoch 60/100
# 64/64 [==============================] - 17s 267ms/step - loss: 0.4003 - accuracy: 0.8203 - val_loss: 0.5888 - val_accuracy: 0.6797
# Epoch 61/100
# 64/64 [==============================] - 16s 252ms/step - loss: 0.3875 - accuracy: 0.8379 - val_loss: 0.5534 - val_accuracy: 0.7734
# Epoch 62/100
# 64/64 [==============================] - 16s 253ms/step - loss: 0.3893 - accuracy: 0.8320 - val_loss: 0.2232 - val_accuracy: 0.8984
# Epoch 63/100
# 64/64 [==============================] - 17s 264ms/step - loss: 0.4086 - accuracy: 0.8096 - val_loss: 0.5749 - val_accuracy: 0.7227
# Epoch 64/100
# 64/64 [==============================] - 16s 250ms/step - loss: 0.4001 - accuracy: 0.8223 - val_loss: 0.2096 - val_accuracy: 0.9180
# Epoch 65/100
# 64/64 [==============================] - 17s 267ms/step - loss: 0.3892 - accuracy: 0.8496 - val_loss: 0.2100 - val_accuracy: 0.9219
# Epoch 66/100
# 64/64 [==============================] - 16s 249ms/step - loss: 0.3790 - accuracy: 0.8174 - val_loss: 0.2245 - val_accuracy: 0.9297
# Epoch 67/100
# 64/64 [==============================] - 17s 264ms/step - loss: 0.3705 - accuracy: 0.8330 - val_loss: 0.6484 - val_accuracy: 0.7227
# Epoch 68/100
# 64/64 [==============================] - 16s 253ms/step - loss: 0.4038 - accuracy: 0.8086 - val_loss: 0.2452 - val_accuracy: 0.9102
# Epoch 69/100
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3823 - accuracy: 0.8438 - val_loss: 0.3821 - val_accuracy: 0.8828
# Epoch 70/100
# 64/64 [==============================] - 16s 254ms/step - loss: 0.3745 - accuracy: 0.8428 - val_loss: 1.5412 - val_accuracy: 0.6016
# Epoch 71/100
# 64/64 [==============================] - 17s 261ms/step - loss: 0.4056 - accuracy: 0.8213 - val_loss: 0.6164 - val_accuracy: 0.7695
# Epoch 72/100
# 64/64 [==============================] - 16s 254ms/step - loss: 0.3803 - accuracy: 0.8301 - val_loss: 0.2925 - val_accuracy: 0.9102
# Epoch 73/100
# 64/64 [==============================] - 17s 262ms/step - loss: 0.3750 - accuracy: 0.8389 - val_loss: 0.4830 - val_accuracy: 0.7617
# Epoch 74/100
# 64/64 [==============================] - 17s 258ms/step - loss: 0.4117 - accuracy: 0.8213 - val_loss: 1.0284 - val_accuracy: 0.5352
# Epoch 75/100
# 64/64 [==============================] - 16s 252ms/step - loss: 0.3626 - accuracy: 0.8477 - val_loss: 0.4787 - val_accuracy: 0.8008
# Epoch 76/100
# 64/64 [==============================] - 18s 272ms/step - loss: 0.3986 - accuracy: 0.8291 - val_loss: 0.8801 - val_accuracy: 0.5664
# Epoch 77/100
# 64/64 [==============================] - 17s 258ms/step - loss: 0.4106 - accuracy: 0.8066 - val_loss: 0.3109 - val_accuracy: 0.8555
# Epoch 78/100
# 64/64 [==============================] - 17s 260ms/step - loss: 0.3762 - accuracy: 0.8301 - val_loss: 0.3578 - val_accuracy: 0.8672
# Epoch 79/100
# 64/64 [==============================] - 17s 258ms/step - loss: 0.3581 - accuracy: 0.8457 - val_loss: 0.8853 - val_accuracy: 0.7344
# Epoch 80/100
# 64/64 [==============================] - 16s 251ms/step - loss: 0.4058 - accuracy: 0.8271 - val_loss: 0.9103 - val_accuracy: 0.7148
# Epoch 81/100
# 64/64 [==============================] - 17s 264ms/step - loss: 0.3719 - accuracy: 0.8428 - val_loss: 0.4434 - val_accuracy: 0.7695
# Epoch 82/100
# 64/64 [==============================] - 17s 257ms/step - loss: 0.3659 - accuracy: 0.8486 - val_loss: 1.0419 - val_accuracy: 0.7305
# Epoch 83/100
# 64/64 [==============================] - 17s 262ms/step - loss: 0.3892 - accuracy: 0.8193 - val_loss: 0.4141 - val_accuracy: 0.8086
# Epoch 84/100
# 64/64 [==============================] - 16s 255ms/step - loss: 0.3852 - accuracy: 0.8301 - val_loss: 3.1532 - val_accuracy: 0.5586
# Epoch 85/100
# 64/64 [==============================] - 17s 263ms/step - loss: 0.3803 - accuracy: 0.8340 - val_loss: 2.9134 - val_accuracy: 0.6523
# Epoch 86/100
# 64/64 [==============================] - 16s 255ms/step - loss: 0.3823 - accuracy: 0.8389 - val_loss: 1.2963 - val_accuracy: 0.5625
# Epoch 87/100
# 64/64 [==============================] - 17s 265ms/step - loss: 0.3930 - accuracy: 0.8223 - val_loss: 0.4752 - val_accuracy: 0.7734
# Epoch 88/100
# 64/64 [==============================] - 17s 265ms/step - loss: 0.3733 - accuracy: 0.8369 - val_loss: 0.3203 - val_accuracy: 0.8594
# Epoch 89/100
# 64/64 [==============================] - 17s 258ms/step - loss: 0.3706 - accuracy: 0.8389 - val_loss: 1.1422 - val_accuracy: 0.5391
# Epoch 90/100
# 64/64 [==============================] - 17s 261ms/step - loss: 0.3857 - accuracy: 0.8340 - val_loss: 0.4452 - val_accuracy: 0.7773
# Epoch 91/100
# 64/64 [==============================] - 16s 255ms/step - loss: 0.3862 - accuracy: 0.8232 - val_loss: 0.2446 - val_accuracy: 0.9375
# Epoch 92/100
# 64/64 [==============================] - 17s 261ms/step - loss: 0.3644 - accuracy: 0.8408 - val_loss: 0.3398 - val_accuracy: 0.8359
# Epoch 93/100
# 64/64 [==============================] - 16s 250ms/step - loss: 0.3522 - accuracy: 0.8438 - val_loss: 0.1962 - val_accuracy: 0.9141
# Epoch 94/100
# 64/64 [==============================] - 17s 268ms/step - loss: 0.3726 - accuracy: 0.8486 - val_loss: 0.4482 - val_accuracy: 0.7578
# Epoch 95/100
# 64/64 [==============================] - 16s 249ms/step - loss: 0.3719 - accuracy: 0.8320 - val_loss: 1.2024 - val_accuracy: 0.5312
# Epoch 96/100
# 64/64 [==============================] - 17s 268ms/step - loss: 0.3841 - accuracy: 0.8311 - val_loss: 0.8949 - val_accuracy: 0.7578
# Epoch 97/100
# 64/64 [==============================] - 16s 250ms/step - loss: 0.3655 - accuracy: 0.8467 - val_loss: 1.0822 - val_accuracy: 0.7070
# Epoch 98/100
# 64/64 [==============================] - 17s 267ms/step - loss: 0.3583 - accuracy: 0.8369 - val_loss: 0.3427 - val_accuracy: 0.8359
# Epoch 99/100
# 64/64 [==============================] - 16s 251ms/step - loss: 0.3659 - accuracy: 0.8262 - val_loss: 0.1589 - val_accuracy: 0.9727
# Epoch 100/100
# 64/64 [==============================] - 17s 257ms/step - loss: 0.3569 - accuracy: 0.8398 - val_loss: 0.6745 - val_accuracy: 0.6758

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()

history_df = pd.DataFrame(history.history)
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Prediction

# %%
y_val_pred = model.predict(x_val)
# Out:
# 8/8 [==============================] - 4s 79ms/step

# %%
accuracy_score(np.argmax(y_val, axis=1), np.argmax(y_val_pred, axis=1))
# Out:
# 0.67578125

# %%
y_pred = model.predict(x_test)
# Out:
# 8/8 [==============================] - 4s 77ms/step

# %%
steps = 10
predictions = []

for i in tqdm(range(steps)):
    preds = model.predict_generator(train_generator.flow(x_test, batch_size=BATCH_SIZE, shuffle=False),
                                    steps = len(x_test)/BATCH_SIZE)
    
    predictions.append(preds)
    gc.collect()
    
y_pred_tta = np.mean(predictions, axis=0)
# Out:
# 100%|██████████| 10/10 [00:39<00:00,  3.98s/it]

# %% [markdown]
# # Confusion Matrix

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Breast Cancer')
# Out:
# Confusion matrix, without normalization
# [[ 89  31]
#  [  1 119]]

# %%
cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred_tta, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Breast Cancer')
# Out:
# Confusion matrix, without normalization
# [[ 80  40]
#  [  1 119]]

# %% [markdown]
# # Classification Report

# %%
from sklearn.metrics import classification_report
classification_report( np.argmax(y_test, axis=1), np.argmax(y_pred_tta, axis=1))
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.99      0.67      0.80       120\n           1       0.75      0.99      0.85       120\n\n    accuracy                           0.83       240\n   macro avg       0.87      0.83      0.82       240\nweighted avg       0.87      0.83      0.82       240\n'

# %% [markdown]
# # ROC & AUC

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(y_test, axis=1), np.argmax(y_pred_tta, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(y_test, axis=1), np.argmax(y_pred_tta, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()
